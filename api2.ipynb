# %%
import opendatasets as od
import pandas as pd

# %% [markdown]
# {"username":"batraccoon","key":"259ecb889a74c206308ef46d501e54fb"}
#
# ketika downlaod file dari keggle, diperlukan password and username. itu termasuk api keys

# %%
od.download('https://www.kaggle.com/datasets/viccalexander/kanyewestverses')
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username:Your Kaggle Key:Downloading kanyewestverses.zip to .\kanyewestverses
# 100%|██████████| 106k/106k [00:00<00:00, 319kB/s]

# %%
df = pd.read_txt('D:\backup\backup\Punya Anggerr\Hacktiv8\API\kanyewestverses\kanye_verses.txt')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df = pd.read_txt('D:\backup\backup\Punya Anggerr\Hacktiv8\API\kanyewestverses\kanye_verses.txt')
#
# AttributeError: module 'pandas' has no attribute 'read_txt'

# %%
od.download('https://www.kaggle.com/datasets/mrmorj/dataset-of-songs-in-spotify')
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username:Your Kaggle Key:Downloading dataset-of-songs-in-spotify.zip to .\dataset-of-songs-in-spotify
# 100%|██████████| 3.06M/3.06M [00:00<00:00, 3.40MB/s]

# %%
rap = pd.read_csv('D:/backup/backup/Punya Anggerr/Hacktiv8/API/dataset-of-songs-in-spotify/genres_v2.csv')

rap
# Out:
# C:\Users\D5att\AppData\Local\Temp\ipykernel_18976\1649162221.py:1: DtypeWarning: Columns (19) have mixed types. Specify dtype option on import or set low_memory=False.
#   rap = pd.read_csv('D:/backup/backup/Punya Anggerr/Hacktiv8/API/dataset-of-songs-in-spotify/genres_v2.csv')
#        danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0             0.831   0.814    2    -7.364     1       0.4200      0.059800
# 1             0.719   0.493    8    -7.230     1       0.0794      0.401000
# 2             0.850   0.893    5    -4.783     1       0.0623      0.013800
# 3             0.476   0.781    0    -4.710     1       0.1030      0.023700
# 4             0.798   0.624    2    -7.668     1       0.2930      0.217000
# ...             ...     ...  ...       ...   ...          ...           ...
# 42300         0.528   0.693    4    -5.148     1       0.0304      0.031500
# 42301         0.517   0.768    0    -7.922     0       0.0479      0.022500
# ...
